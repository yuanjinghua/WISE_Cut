# %%
import warnings
warnings.filterwarnings("ignore")
import os
import math
import time
import tarfile
import shutil
import aplpy as ap
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import montage_wrapper as mt
from astropy.io import ascii,fits
from astropy.table import Table, Column, vstack, join
from astropy import units as u
import astropy.coordinates as coords

mpl.rc("font", family="serif", size=15)
mpl.rc("axes", linewidth = 1)
mpl.rc("lines", linewidth = 1)
mpl.rc("xtick.major", size = 6, pad = 5, width = 1)
mpl.rc("ytick.major", size = 6,  pad = 5, width = 1)
mpl.rc("xtick.minor", size = 3,  width = 1)
mpl.rc("ytick.minor", size = 3,  width = 1)

#ap.make_rgb_cube(['M31_w3.fits', 
#                  'M31_w2.fits',
#                  'M31_w1.fits'],
#                  'M31_wiseRGB.fits',
#                 north=True)
    
ap.make_rgb_image('M31_wiseRGB.fits', 
                  'M31_wiseRGB.png',
                  pmin_r = 0.1, pmax_r = 99.9, 
                  pmin_g = 0.1, pmax_g = 99.9,
                  pmin_b = 0.1, pmax_b = 99.9, 
                  stretch_r='log', stretch_g='log',
                  stretch_b='log',
                  embed_avm_tags = False)
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  4.034e+02 (auto) [aplpy.rgb]
# INFO: vmax =  4.839e+02 (auto) [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  8.160e+00 (auto) [aplpy.rgb]
# INFO: vmax =  1.545e+02 (auto) [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  2.744e+00 (auto) [aplpy.rgb]
# INFO: vmax =  3.614e+02 (auto) [aplpy.rgb]

# %%
# %matplotlib inline
ap.make_rgb_image('M31_wiseRGB.fits', 
                  'M31_wiseRGB.png',
                  pmin_r = 10, pmax_r = 99.9, 
                  pmin_g = 0.05, pmax_g = 99.7,
                  pmin_b = 0.05, pmax_b = 99.5, 
                  stretch_r='log', stretch_g='log',
                  stretch_b='log',
                  embed_avm_tags = False)
f = ap.FITSFigure('M31_w2.fits')
f.show_rgb('M31_wiseRGB.png')
# Out:
# INFO: Red: [aplpy.rgb]
# INFO: vmin =  4.047e+02 (auto) [aplpy.rgb]
# INFO: vmax =  4.839e+02 (auto) [aplpy.rgb]
# INFO: Green: [aplpy.rgb]
# INFO: vmin =  8.140e+00 (auto) [aplpy.rgb]
# INFO: vmax =  6.808e+01 (auto) [aplpy.rgb]
# INFO: Blue: [aplpy.rgb]
# INFO: vmin =  2.724e+00 (auto) [aplpy.rgb]
# INFO: vmax =  1.024e+02 (auto) [aplpy.rgb]
